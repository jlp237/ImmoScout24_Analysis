# %% [markdown]
# # Inhalt
# ---
# *  [1. Daten einlesen](#Daten-einlesen)
# *  [Frage 1](#Frage-1)

# %% [markdown]
# # Daten einlesen
# ---
# * Zuerst werden die Daten aus der DB eingelesen

# %%
# DB Connection zur Mongo DB

import pymongo
from pymongo import MongoClient
import pandas as pd


client = pymongo.MongoClient("mongodb://admin:admin123@dst-shard-00-00-xd93f.mongodb.net:27017,dst-shard-00-01-xd93f.mongodb.net:27017,dst-shard-00-02-xd93f.mongodb.net:27017/immo_data?ssl=true&replicaSet=DST-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.IMMO_DATA

# s is the name of the collection
s = '2019-11-25-17-45'

collection = db[s]

#queries all the objects in the collection and saves them into a cursor
cursor = collection.find({})

## formats the collection to pandas dataframe
df =  pd.DataFrame(list(cursor))
df
# Out:
#    Haus/Wohnung         ID Miete/Kauf                       _id  \
# 0       Wohnung  114545643      Miete  5ddc0536858533c23e321f45
# 1       Wohnung  114093709      Miete  5ddc0536858533c23e321f3b
# 2       Wohnung  112184410      Miete  5ddc0536858533c23e321f31
# 3       Wohnung  114451141      Miete  5ddc0536858533c23e321f51
# 4       Wohnung  114455971      Miete  5ddc0536858533c23e321f52
# 5       Wohnung  114457012      Miete  5ddc0536858533c23e321f4e
# 6       Wohnung  114576306      Miete  5ddc0536858533c23e321f3f
# 7       Wohnung  114019935      Miete  5ddc0536858533c23e321f2e
# 8       Wohnung  113671571      Miete  5ddc0536858533c23e321f4a
# 9       Wohnung  114344484      Miete  5ddc0536858533c23e321f32
# 10      Wohnung  114298970      Miete  5ddc0536858533c23e321f47
# 11      Wohnung  114580208      Miete  5ddc0536858533c23e321f44
# 12      Wohnung  114153495      Miete  5ddc0536858533c23e321f4d
# 13      Wohnung  113166183      Miete  5ddc0536858533c23e321f46
# ...

# %%
import pandas as pd 
df = pd.read_csv("/Users/jan-lukaspflaum/Downloads/2019-11-25-15-16-Wohnung-Miete.csv", header = 1) 
df
# Out:
#              ID Miete/Kauf Haus/Wohnung  \
# 0     114019935      Miete      Wohnung
# 1     114012650      Miete      Wohnung
# 2     112406554      Miete      Wohnung
# 3     112184410      Miete      Wohnung
# 4     114344484      Miete      Wohnung
# 5     113577177      Miete      Wohnung
# 6     112596373      Miete      Wohnung
# 7     113931904      Miete      Wohnung
# 8     114380997      Miete      Wohnung
# 9     114364080      Miete      Wohnung
# 10    114589726      Miete      Wohnung
# 11    114304917      Miete      Wohnung
# 12    114437800      Miete      Wohnung
# 13    114093709      Miete      Wohnung
# 14    113144431      Miete      Wohnung
# 15    114039555      Miete      Wohnung
# 16    113994153      Miete      Wohnung
# 17    114576306      Miete      Wohnung
# 18    112897021      Miete      Wohnung
# 19    114153452      Miete      Wohnung
# 20    114564773      Miete      Wohnung
# 21    113582322      Miete      Wohnung
# ...

# %%
df.loc[df['price'].idxmin()]
# Out:
# ID                                                        72793073
# Miete/Kauf                                                   Miete
# Haus/Wohnung                                               Wohnung
# address              Gatower Straße 169, Spandau (Spandau), Berlin
# city                                                        Berlin
# postcode                                                     13595
# quarter                                          Spandau (Spandau)
# lat                                                         52.505
# lon                                                        13.1806
# title                           Großes möbliertes Zimmer in 2er WG
# numberOfRooms                                                    1
# livingSpace                                                     23
# balcony                                                          0
# builtInKitchen                                                   1
# ...

# %% [markdown]
# ## Ausdrucken der Spalten
# ---

# %%
# list columns and datatypes 

for col in df.columns: 
    print(col)
    print(type(col[0]))
# Out:
# ID
# <class 'str'>
# Miete/Kauf
# <class 'str'>
# Haus/Wohnung
# <class 'str'>
# address
# <class 'str'>
# city
# <class 'str'>
# postcode
# <class 'str'>
# quarter
# <class 'str'>
# lat
# <class 'str'>
# lon
# <class 'str'>
# title
# <class 'str'>
# numberOfRooms
# <class 'str'>
# livingSpace
# <class 'str'>
# balcony
# <class 'str'>
# builtInKitchen
# <class 'str'>
# garden
# <class 'str'>
# price
# <class 'str'>
# privateOffer
# <class 'str'>
# floorplan
# <class 'str'>
# from
# <class 'str'>
# ID.1
# <class 'str'>
# url
# <class 'str'>

# %%
# Fehlererkennung in row "ID"

for index, row in df.iterrows():
    print(index, row['ID'])
    
print(df["ID"][1432])
# Out:
# 0 114019935
# 1 114012650
# 2 112406554
# 3 112184410
# 4 114344484
# 5 113577177
# 6 112596373
# 7 113931904
# 8 114380997
# 9 114364080
# 10 114589726
# 11 114304917
# 12 114437800
# 13 114093709
# 14 113144431
# 15 114039555
# 16 113994153
# 17 114576306
# 18 112897021
# 19 114153452
# 20 114564773
# 21 113582322
# 22 114580208
# 23 114545643
# 24 113166183
# 25 114298970
# 26 114272612
# 27 114395901
# 28 114153495
# 29 114457012
# 30 114456976
# 31 114012748
# 32 114451141
# 33 114455971
# 34 113934347
# 35 112035318
# 36 114103834
# 37 112917184
# 38 114250505
# 39 114381102
# 40 114572178
# 41 114380995
# 42 83976863
# 43 114250071
# 44 114496251
# 45 114456694
# 46 113968940
# 47 105152382
# 48 98249429
# 49 90918322
# 50 90220687
# 51 81288239
# 52 74611297
# 53 74274817
# 54 113373018
# 55 114589724
# 56 114335520
# 57 110759860
# 58 110760507
# 59 105943305
# 60 114581339
# 61 114471202
# 62 114470183
# 63 114289429
# 64 114289431
# 65 114294891
# 66 114294900
# ...

# %%
# drop error rows 
df = df.drop(1432)

# %%
# convert datatypes of "ID"
df['ID'] = df['ID'].astype(int)

# %%
# Fehlererkennung in row "ID"

for index, row in df.iterrows():
    print(index, row['ID.1'])
# Out:
# 0 114019935.0
# 1 114012650.0
# 2 112406554.0
# 3 112184410.0
# 4 114344484.0
# 5 113577177.0
# 6 112596373.0
# 7 113931904.0
# 8 114380997.0
# 9 114364080.0
# 10 114589726.0
# 11 114304917.0
# 12 114437800.0
# 13 114093709.0
# 14 113144431.0
# 15 114039555.0
# 16 113994153.0
# 17 114576306.0
# 18 112897021.0
# 19 114153452.0
# 20 114564773.0
# 21 113582322.0
# 22 114580208.0
# 23 114545643.0
# 24 113166183.0
# 25 114298970.0
# 26 114272612.0
# 27 114395901.0
# 28 114153495.0
# 29 114457012.0
# 30 114456976.0
# 31 114012748.0
# 32 114451141.0
# 33 114455971.0
# 34 113934347.0
# 35 112035318.0
# 36 114103834.0
# 37 112917184.0
# 38 114250505.0
# 39 114381102.0
# 40 114572178.0
# 41 114380995.0
# 42 83976863.0
# 43 114250071.0
# 44 114496251.0
# 45 114456694.0
# 46 113968940.0
# 47 105152382.0
# 48 98249429.0
# 49 90918322.0
# 50 90220687.0
# 51 81288239.0
# 52 74611297.0
# 53 74274817.0
# 54 113373018.0
# 55 114589724.0
# 56 114335520.0
# 57 110759860.0
# 58 110760507.0
# ...

# %%
# error row nr. 2 
df = df.drop(1431)

# %%
df['postcode'] = df['postcode'].astype(int)

# %%
df['lat'] = df['lat'].astype(float)

# %%
df['lon'] = df['lon'].astype(float)

# %%
df['numberOfRooms'] = df['numberOfRooms'].astype(float)

# %%
df['livingSpace'] = df['livingSpace'].astype(float)

# %%
df['price'] = df['price'].astype(float)

# %%
df['ID.1'] = df['ID.1'].astype(int)

# %%
# histograms
from matplotlib import pyplot
# %matplotlib notebook
df[["livingSpace", "price",'balcony', 'builtInKitchen', 'garden', 'privateOffer', 'floorplan']].hist(bins = 30)
pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="943">

# %%
# scatter plot matrix
from pandas.plotting import scatter_matrix
# %matplotlib notebook

scatter_matrix(df[['numberOfRooms','livingSpace','price']])

pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="935">

# %%
# scatter plot matrix
from pandas.plotting import scatter_matrix
# %matplotlib notebook

scatter_matrix(df[["numberOfRooms", "livingSpace", "price",'balcony']])

pyplot.show()
# Out:
# <img src="data:image/png;base64,..." width="925">

# %%
# change boolean to int 1 and 0 

df[['balcony', 'builtInKitchen', 'garden', 'privateOffer', 'floorplan']] = (df[['balcony', 'builtInKitchen', 'garden', 'privateOffer', 'floorplan']]).astype(int)
df
# Out:
#              ID Miete/Kauf Haus/Wohnung  \
# 0     114019935      Miete      Wohnung
# 1     114012650      Miete      Wohnung
# 2     112406554      Miete      Wohnung
# 3     112184410      Miete      Wohnung
# 4     114344484      Miete      Wohnung
# 5     113577177      Miete      Wohnung
# 6     112596373      Miete      Wohnung
# 7     113931904      Miete      Wohnung
# 8     114380997      Miete      Wohnung
# 9     114364080      Miete      Wohnung
# 10    114589726      Miete      Wohnung
# 11    114304917      Miete      Wohnung
# 12    114437800      Miete      Wohnung
# 13    114093709      Miete      Wohnung
# 14    113144431      Miete      Wohnung
# 15    114039555      Miete      Wohnung
# 16    113994153      Miete      Wohnung
# 17    114576306      Miete      Wohnung
# 18    112897021      Miete      Wohnung
# 19    114153452      Miete      Wohnung
# 20    114564773      Miete      Wohnung
# 21    113582322      Miete      Wohnung
# ...

# %% [markdown]
# # Frage 1
# ## Frage 2
# ### Frage 3
# ---
# *Antwort:*
